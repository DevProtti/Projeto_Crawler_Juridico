# %%
# ============================================
# COMO MOSTRAR TODOS OS ATRIBUTOS DE UM OBJETO
# ============================================

import inspect
import json
from pprint import pprint

def mostrar_atributos(obj, nome="objeto"):
    """
    Função utilitária para mostrar todos os atributos de um objeto Python.
    
    Args:
        obj: O objeto a ser inspecionado
        nome: Nome descritivo do objeto (opcional)
    """
    print(f"\n{'='*60}")
    print(f"📋 INSPEÇÃO DO OBJETO: {nome}")
    print(f"{'='*60}\n")
    
    # 1. Tipo do objeto
    print(f"🔹 Tipo: {type(obj).__name__}")
    print(f"🔹 Módulo: {type(obj).__module__}\n")
    
    # 2. Listar todos os atributos e métodos com dir()
    print("📌 TODOS OS ATRIBUTOS E MÉTODOS (dir()):")
    print("-" * 60)
    atributos = [attr for attr in dir(obj) if not attr.startswith('_')]
    for attr in atributos:
        print(f"  • {attr}")
    print()
    
    # 3. Atributos de instância (valores reais)
    print("📌 ATRIBUTOS DE INSTÂNCIA (vars() ou __dict__):")
    print("-" * 60)
    try:
        if hasattr(obj, '__dict__'):
            for key, value in vars(obj).items():
                tipo_valor = type(value).__name__
                if isinstance(value, (str, int, float, bool, type(None))):
                    print(f"  • {key}: {value} ({tipo_valor})")
                elif isinstance(value, (list, dict)):
                    print(f"  • {key}: {tipo_valor} com {len(value)} item(s)")
                else:
                    print(f"  • {key}: {tipo_valor}")
        else:
            print("  (Objeto não possui __dict__)")
    except Exception as e:
        print(f"  Erro ao acessar vars(): {e}")
    print()
    
    # 4. Informações de inspeção (métodos, propriedades, etc.)
    print("📌 INFORMAÇÕES DETALHADAS (inspect):")
    print("-" * 60)
    try:
        # Membros do objeto
        membros = inspect.getmembers(obj)
        metodos = [nome for nome, valor in membros if inspect.ismethod(valor) or inspect.isfunction(valor)]
        propriedades = [nome for nome, valor in membros if isinstance(valor, property)]
        
        if metodos:
            print(f"  🔸 Métodos ({len(metodos)}):")
            for metodo in metodos[:10]:  # Mostra apenas os primeiros 10
                print(f"     - {metodo}()")
            if len(metodos) > 10:
                print(f"     ... e mais {len(metodos) - 10} método(s)")
        
        if propriedades:
            print(f"  🔸 Propriedades ({len(propriedades)}):")
            for prop in propriedades:
                print(f"     - {prop}")
    except Exception as e:
        print(f"  Erro na inspeção: {e}")
    print()
    
    # 5. Tentar converter para dict se possível (útil para Pydantic models)
    print("📌 REPRESENTAÇÃO EM DICT (se disponível):")
    print("-" * 60)
    try:
        if hasattr(obj, 'model_dump'):
            # Pydantic v2
            dict_repr = obj.model_dump()
            print(json.dumps(dict_repr, indent=2, ensure_ascii=False, default=str)[:500])
        elif hasattr(obj, 'dict'):
            # Pydantic v1
            dict_repr = obj.dict()
            print(json.dumps(dict_repr, indent=2, ensure_ascii=False, default=str)[:500])
        elif hasattr(obj, '__dict__'):
            dict_repr = vars(obj)
            print(json.dumps(dict_repr, indent=2, ensure_ascii=False, default=str)[:500])
        else:
            print("  (Não é possível converter para dict)")
    except Exception as e:
        print(f"  Erro ao converter: {e}")
    
    print(f"\n{'='*60}\n")

# Exemplo de uso rápido (versão simplificada)
def mostrar_atributos_rapido(obj):
    """Versão rápida - mostra apenas os atributos principais"""
    print(f"\n🔍 Atributos de {type(obj).__name__}:")
    print("-" * 40)
    for attr in dir(obj):
        if not attr.startswith('_'):
            try:
                valor = getattr(obj, attr)
                if not callable(valor):
                    tipo = type(valor).__name__
                    if isinstance(valor, (str, int, float, bool, type(None))):
                        print(f"  {attr}: {valor} ({tipo})")
                    elif isinstance(valor, (list, dict)):
                        print(f"  {attr}: {tipo} com {len(valor)} item(s)")
                    else:
                        print(f"  {attr}: {tipo}")
            except:
                print(f"  {attr}: (não acessível)")
    print()

print("✅ Funções de inspeção carregadas!")
print("   Use: mostrar_atributos(objeto, 'nome_descritivo')")
print("   Ou:  mostrar_atributos_rapido(objeto)")
# Out:
# ✅ Funções de inspeção carregadas!
#    Use: mostrar_atributos(objeto, 'nome_descritivo')
#    Ou:  mostrar_atributos_rapido(objeto)

# %%
# ============================================
# EXEMPLO: Inspecionar um CrawlResult
# ============================================

async def exemplo_inspecionar_resultado():
    """Exemplo de como inspecionar todos os atributos de um CrawlResult"""
    
    async with AsyncWebCrawler() as crawler:
        results = await crawler.arun(
            url="https://predictus.inf.br/",
            config=CrawlerRunConfig()
        )
        
        if results:
            result = results[0]  # Pega o primeiro resultado
            
            # Opção 1: Usar a função completa
            mostrar_atributos(result, "CrawlResult")
            
            # Opção 2: Usar a versão rápida
            # mostrar_atributos_rapido(result)
            
            # Opção 3: Métodos manuais rápidos
            print("\n" + "="*60)
            print("🔧 MÉTODOS MANUAIS RÁPIDOS:")
            print("="*60)
            
            print("\n1️⃣ dir() - Lista todos os atributos:")
            print([attr for attr in dir(result) if not attr.startswith('_')][:10])
            
            print("\n2️⃣ vars() ou __dict__ - Atributos de instância:")
            for key in list(vars(result).keys())[:5]:
                print(f"   {key}: {type(getattr(result, key)).__name__}")
            
            print("\n3️⃣ type() - Tipo do objeto:")
            print(f"   {type(result)}")
            
            print("\n4️⃣ hasattr() - Verificar se tem atributo específico:")
            print(f"   Tem 'markdown'? {hasattr(result, 'markdown')}")
            print(f"   Tem 'links'? {hasattr(result, 'links')}")
            print(f"   Tem 'media'? {hasattr(result, 'media')}")
            
            print("\n5️⃣ getattr() - Acessar atributo com valor padrão:")
            print(f"   success: {getattr(result, 'success', 'N/A')}")
            print(f"   url: {getattr(result, 'url', 'N/A')}")
            
            return result

# Descomente para executar:
# await exemplo_inspecionar_resultado()

# %% [markdown]
# # 📚 RESUMO: Como Mostrar Todos os Atributos de um Objeto em Python
#
# ## 🔧 Métodos Básicos
#
# ### 1. **`dir(objeto)`** - Lista todos os atributos e métodos
# ```python
# # Mostra tudo (incluindo métodos privados)
# dir(resultado)
#
# # Apenas atributos públicos
# [attr for attr in dir(resultado) if not attr.startswith('_')]
# ```
#
# ### 2. **`vars(objeto)` ou `objeto.__dict__`** - Atributos de instância
# ```python
# # Mostra apenas atributos de instância (valores reais)
# vars(resultado)
# resultado.__dict__
# ```
#
# ### 3. **`type(objeto)`** - Tipo do objeto
# ```python
# type(resultado)  # <class 'crawl4ai.models.CrawlResult'>
# type(resultado).__name__  # 'CrawlResult'
# ```
#
# ### 4. **`hasattr(objeto, 'atributo')`** - Verificar se tem atributo
# ```python
# hasattr(resultado, 'markdown')  # True ou False
# ```
#
# ### 5. **`getattr(objeto, 'atributo', default)`** - Acessar com valor padrão
# ```python
# getattr(resultado, 'markdown', None)  # Retorna None se não existir
# ```
#
# ### 6. **`inspect` module** - Inspeção avançada
# ```python
# import inspect
#
# # Todos os membros
# inspect.getmembers(resultado)
#
# # Apenas métodos
# [nome for nome, valor in inspect.getmembers(resultado) if inspect.ismethod(valor)]
#
# # Apenas propriedades
# [nome for nome, valor in inspect.getmembers(resultado) if isinstance(valor, property)]
# ```
#
# ## 🎯 Para Objetos Específicos
#
# ### Pydantic Models (v2)
# ```python
# resultado.model_dump()  # Converte para dict
# resultado.model_fields  # Campos do modelo
# ```
#
# ### Pydantic Models (v1)
# ```python
# resultado.dict()  # Converte para dict
# resultado.__fields__  # Campos do modelo
# ```
#
# ## 💡 Exemplo Prático com CrawlResult
#
# ```python
# # Inspecionar um resultado do crawl4ai
# result = await crawler.arun(url="...")
#
# # Ver todos os atributos
# mostrar_atributos(result, "CrawlResult")
#
# # Ou versão rápida
# mostrar_atributos_rapido(result)
#
# # Ou manualmente
# print([attr for attr in dir(result) if not attr.startswith('_')])
# print(vars(result))
# ```

# %%
import asyncio
from crawl4ai import AsyncWebCrawler, CrawlResult, CrawlerRunConfig
from typing import List

# %%
async def demo_basic_crawl():
    """Basic web crawling with markdown generation"""

    print("\n=== 1. Basic Web Crawling ===")

    async with AsyncWebCrawler() as crawler:
        results: List[CrawlResult] = await crawler.arun(
            url="https://www.jusbrasil.com.br/noticias/",
            config=CrawlerRunConfig()
        )

        for i, result in enumerate(results):
            print(f"Result {i + 1}:")
            print(f"Success: {result.success}")

            if result.success:
                print(f"Markdown length: {len(result.markdown.raw_markdown)} chars")
                print(f"First 100 characters: {result.markdown.raw_markdown[:100]}...")
            else:
                print("Failed to crawl the URL")

# %%
await demo_basic_crawl()
# Out:
# === 1. Basic Web Crawling ===
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 3.26s
# [SCRAPE].. ◆ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 0.23s
# [COMPLETE] ● https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 3.50s
# Result 1:
# Success: True
# Markdown length: 22383 chars
# First 100 characters: Newsletter
# Receba por e-mail as publicações mais relevantes[Inscreva-se](https://www.jusbrasil.com.b...

# %%
async def demo_parallel_crawl():
    """Basic web crawling with markdown generation"""

    print("\n=== 2. Basic Web Crawling ===")

    urls = [
        "https://www.jusbrasil.com.br/noticias/",
        "https://predictus.inf.br/"
    ]

    async with AsyncWebCrawler() as crawler:
        results: List[CrawlResult] = await crawler.arun_many(
            urls=urls,
        )


        print(f"Crawled {len(results)} URL's in parallel")
        for i, result in enumerate(results):
            print(
                f"  {i + 1} - {result.url} - {'Success' if result.success else 'Failed'}"
            )

# %%
await demo_parallel_crawl()
# Out:
# === 2. Basic Web Crawling ===
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 5.20s
# [SCRAPE].. ◆ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 0.31s
# [COMPLETE] ● https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 5.53s
# [FETCH]... ↓ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 7.44s
# [SCRAPE].. ◆ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 0.21s
# [COMPLETE] ● https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 7.65s
# Crawled 2 URL's in parallel
#   1 - https://www.jusbrasil.com.br/noticias/ - Success
#   2 - https://predictus.inf.br/ - Success

# %%
from crawl4ai.markdown_generation_strategy import DefaultMarkdownGenerator
from crawl4ai.content_filter_strategy import PruningContentFilter

async def demo_fit_markdown():
    """"""
    
    print("\n=== 3. Fit Markdown with LLM Content Filter ===")

    async with AsyncWebCrawler() as crawler:
        result: CrawlResult = await crawler.arun(
            url="https://predictus.inf.br/",
            config=CrawlerRunConfig(
                markdown_generator=DefaultMarkdownGenerator(
                    content_filter=PruningContentFilter()
                )
            )
        )

        print(f"Raw: {len(result.markdown.raw_markdown)} chars")
        print(f"Fit: {len(result.markdown.fit_markdown)} chars")

# %%
await demo_fit_markdown()
# Out:
# === 3. Fit Markdown with LLM Content Filter ===
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 9.36s
# [SCRAPE].. ◆ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 0.68s
# [COMPLETE] ● https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 10.05s
# Raw: 20394 chars
# Fit: 13639 chars

# %%
import json

async def demo_midia_crawl():
    """Crawl a website with media files"""

    print("\n=== 4. Media Crawl ===")

    async with AsyncWebCrawler() as crawler:
        results: List[CrawlResult] = await crawler.arun(url="https://predictus.inf.br/")

        for i, result in enumerate(results):
            # extract and save all media
            images = result.media.get("images", [])
            print(f"Found {len(images)} images")

            # Extract and save all links (internal and external)
            internal_links = result.links.get("internal", [])
            external_links = result.links.get("external", [])
            print(f"Found {len(internal_links)} internal links")
            print(f"Found {len(external_links)} external links")

            # save all links to a file
            with open("images.json", "w") as f:
                json.dump(images, f, indent=2)

            with open("links.json", "w") as f:
                json.dump(
                    {
                        "internal": internal_links,
                        "external": external_links,
                    },
                    f,
                    indent=2
                )

# %%
await demo_midia_crawl()
# Out:
# === 4. Media Crawl ===
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 4.29s
# [SCRAPE].. ◆ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 0.25s
# [COMPLETE] ● https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 4.54s
# Found 17 images
# Found 23 internal links
# Found 9 external links

# %%
import base64
import os
from pathlib import Path

async def demo_screenshot_and_pdf_crawl():
    """Crawl a website and save screenshot and PDF"""

    print("\n=== 5. Screenshot and PDF Crawl ===")

    # Obter o diretório atual
    current_dir = Path.cwd()
    tmp_dir = current_dir / "tmp"
    tmp_dir.mkdir(exist_ok=True)  # Criar o diretório tmp se não existir

    async with AsyncWebCrawler() as crawler:
        results: List[CrawlResult] = await crawler.arun(
            url="https://predictus.inf.br/",
            config=CrawlerRunConfig(screenshot=True, pdf=True)
        )

        for i, result in enumerate(results):
            if result.screenshot:
                screenshot_path = tmp_dir / "exemple_screenshot.png"
                with open(screenshot_path, "wb") as f:
                    f.write(base64.b64decode(result.screenshot))
                print(f"Screenshot saved to {screenshot_path}")

            if result.pdf:
                pdf_path = tmp_dir / "exemple.pdf"
                with open(pdf_path, "wb") as f:
                    f.write(result.pdf)
                print(f"PDF saved to {pdf_path}")

# %%
await demo_screenshot_and_pdf_crawl()
# Out:
# === 5. Screenshot and PDF Crawl ===
# [INIT].... → Crawl4AI 0.7.7
# [EXPORT].. ℹ Exporting media (PDF/MHTML/screenshot) took 2.41s
# [FETCH]... ↓ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 6.93s
# [SCRAPE].. ◆ https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 0.16s
# [COMPLETE] ● https://predictus.inf.br/                                                                            |
# ✓ | ⏱: 7.10s
# Screenshot saved to /home/gabriel/Documentos/Projetos_Python/Projeto_Crawler_Juridico/testes/tmp/exemple_screenshot.png
# PDF saved to /home/gabriel/Documentos/Projetos_Python/Projeto_Crawler_Juridico/testes/tmp/exemple.pdf

# %%
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode, LLMConfig
from crawl4ai import LLMExtractionStrategy
from dotenv import load_dotenv, find_dotenv
import os

load_dotenv(find_dotenv())


GROQ_API_KEY = os.environ.get("GROQ_API_KEY", "")

async def demo_llm_structtured_extraction_no_schema():

    print("\n=== 6. LLM Structured Extraction (No Schema) ===")

    extraction_strategy = LLMExtractionStrategy(
        llm_config=LLMConfig(
            provider="groq/llama-3.3-70b-versatile",
            api_token=GROQ_API_KEY  # Ollama não requer API key
        ),
        instruction="Esse é o blog do JusBrasil, um site especializado em notícias jurídicas. Extraia todas as noticias e para cada uma eu qeuro que você traga o título, URL fonte e número de comentários",
        extract_type="schema",
        schema="{titile: string, url: string, comments: int}",
        extra_agrs={
            "temperature": 0.0,
            "max_tokens": 4096,
        },
        verbose=True
    )

    config = CrawlerRunConfig(extraction_strategy=extraction_strategy)

    async with AsyncWebCrawler() as crawler:
        results: List[CrawlResult] = await crawler.arun(
            url = "https://www.jusbrasil.com.br/noticias/", 
            config=config
        )

        for result in results:
            print(f"URL: {result.url}")
            print(f"Success: {result.success}")

            if result.success:
                data = json.loads(result.extracted_content)
                print(json.dumps(data, indent=2))
            else:
                print("Failed to extract information")

# %%
await demo_llm_structtured_extraction_no_schema()
# Out:
# === 6. LLM Structured Extraction (No Schema) ===
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 2.81s
# [SCRAPE].. ◆ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 0.19s
# [LOG] Call LLM for https://www.jusbrasil.com.br/noticias/ - block index: 0
# [LOG] Extracted 20 blocks from URL: https://www.jusbrasil.com.br/noticias/ block index: 0
# [EXTRACT]. ■ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 5.99s
# [COMPLETE] ● https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 9.01s
# URL: https://www.jusbrasil.com.br/noticias/
# Success: True
# [
#   {
#     "title": "Limite de idade unificado para ingresso na PM e Corpo de Bombeiros passa na CCJ",
#     "url": "https://www.jusbrasil.com.br/noticias/limite-de-idade-unificado-para-ingresso-na-pm-e-corpo-de-bombeiros-passa-na-ccj/5340390608",
#     "comments": 3,
#     "error": false
#   },
#   {
#     "title": "Aposentadoria especial para agentes de sa\u00fade ser\u00e1 votada na ter\u00e7a, anuncia Davi",
#     "url": "https://www.jusbrasil.com.br/noticias/aposentadoria-especial-para-agentes-de-saude-sera-votada-na-terca-anuncia-davi/5324286431",
#     "comments": 2,
#     "error": false
#   },
#   {
#     "title": "CPMI: Carlos Viana defende suspens\u00e3o de empr\u00e9stimos consignados de aposentados",
#     "url": "https://www.jusbrasil.com.br/noticias/cpmi-carlos-viana-defende-suspensao-de-emprestimos-consignados-de-aposentados/5314638551",
#     "comments": 3,
#     "error": false
#   },
#   {
#     "title": "Paciente ser\u00e1 indenizada em R$ 3 mil ap\u00f3s plano de sa\u00fade negar exame de mapeamento venoso",
#     "url": "https://www.jusbrasil.com.br/noticias/paciente-sera-indenizada-em-r-3-mil-apos-plano-de-saude-negar-exame-de-mapeamento-venoso/5302560890",
#     "comments": 5,
#     "error": false
#   },
#   {
#     "title": "Estande Sistema Tribunais de Contas aborda controle social e educa\u00e7\u00e3o ambiental em palestras na Green Zone",
#     "url": "https://www.jusbrasil.com.br/noticias/estande-sistema-tribunais-de-contas-aborda-controle-social-e-educacao-ambiental-em-palestras-na-green-zone/5303911722",
#     "comments": 0,
#     "error": false
#   },
#   {
#     "title": "Semin\u00e1rio do MPRS debate radicaliza\u00e7\u00e3o, \u00f3dio e novas formas de extremismo violento",
#     "url": "https://www.jusbrasil.com.br/noticias/seminario-do-mprs-debate-radicalizacao-odio-e-novas-formas-de-extremismo-violento/5293732186",
#     "comments": 0,
#     "error": false
#   },
#   {
#     "title": "Judici\u00e1rio de Olho d\u00c1gua das Cunh\u00e3s realiza juris",
#     "url": "https://www.jusbrasil.com.br/noticias/judiciario-de-olho-dagua-das-cunhas-realiza-juris/5291394943",
#     "comments": 0,
#     "error": false
#   },
#   {
#     "title": "Corte Especial cancela sess\u00e3o extraordin\u00e1ria prevista para segunda-feira (10)",
#     "url": "https://www.jusbrasil.com.br/noticias/corte-especial-cancela-sessao-extraordinaria-prevista-para-segunda-feira-10/5283524021",
#     "comments": 0,
#     "error": false
#   },
#   {
#     "title": "MPRJ realiza evento sobre desastres socioambientais e lan\u00e7a Comiss\u00e3o Permanente de Estudos sobre o tema",
#     "url": "https://www.jusbrasil.com.br/noticias/mprj-realiza-evento-sobre-desastres-socioambientais-e-lanca-comissao-permanente-de-estudos-sobre-o-tema/5285734590",
#     "comments": 1,
#     "error": false
#   },
#   {
#     "title": "Encontro com tribunais de segundo grau debate riscos e vantagens do uso da IA no Judici\u00e1rio",
#     "url": "https://www.jusbrasil.com.br/noticias/encontro-com-tribunais-de-segundo-grau-debate-riscos-e-vantagens-do-uso-da-ia-no-judiciario/5271585815",
#     "comments": 3,
#     "error": false
#   },
#   {
#     "title": "MPF obt\u00e9m decis\u00e3o que obriga Incra a regularizar projeto de assentamento em Magalh\u00e3es de Almeida (MA)",
#     "url": "https://www.jusbrasil.com.br/noticias/mpf-obtem-decisao-que-obriga-incra-a-regularizar-projeto-de-assentamento-em-magalhaes-de-almeida-ma/5271609545",
#     "comments": 1,
#     "error": false
#   },
#   {
#     "title": "Lei refor\u00e7a prote\u00e7\u00e3o a autoridades e endurece puni\u00e7\u00f5es contra crime organizado",
#     "url": "https://www.jusbrasil.com.br/noticias/lei-reforca-protecao-a-autoridades-e-endurece-punicoes-contra-crime-organizado/5259044418",
#     "comments": 3,
#     "error": false
#   },
#   {
#     "title": "CeLesTe: MTE apresenta assistente virtual para facilitar acesso a informa\u00e7\u00f5es trabalhistas",
#     "url": "https://www.jusbrasil.com.br/noticias/celeste-mte-apresenta-assistente-virtual-para-facilitar-acesso-a-informacoes-trabalhistas/5206884098",
#     "comments": 3,
#     "error": false
#   },
#   {
#     "title": "Feriado suspende expediente e prazos processuais em Bel\u00e9m",
#     "url": "https://www.jusbrasil.com.br/noticias/feriado-suspende-expediente-e-prazos-processuais-em-belem/5206887118",
#     "comments": 0,
#     "error": false
#   },
#   {
#     "title": "Sancionada lei que torna ato il\u00edcito civil o abandono afetivo de crian\u00e7a e adolescente",
#     "url": "https://www.jusbrasil.com.br/noticias/sancionada-lei-que-torna-ato-ilicito-civil-o-abandono-afetivo-de-crianca-e-adolescente/5201762386",
#     "comments": 9,
#     "error": false
#   },
#   {
#     "title": "MPT defende legisla\u00e7\u00e3o para regulamentar trabalho sazonal de migrantes",
#     "url": "https://www.jusbrasil.com.br/noticias/mpt-defende-legislacao-para-regulamentar-trabalho-sazonal-de-migrantes/5205811182",
#     "comments": 3,
#     "error": false
#   },
#   {
#     "title": "Justi\u00e7a condena conselheiros tutelares por n\u00e3o acompanharem crian\u00e7as em depoimento especial",
#     "url": "https://www.jusbrasil.com.br/noticias/justica-condena-conselheiros-tutelares-por-nao-acompanharem-criancas-em-depoimento-especial/5187958965",
#     "comments": 4,
#     "error": false
#   },
#   {
#     "title": "PJe: autentica\u00e7\u00e3o em dois fatores ter\u00e1 mudan\u00e7a a partir de segunda-feira (3/11)",
#     "url": "https://www.jusbrasil.com.br/noticias/pje-autenticacao-em-dois-fatores-tera-mudanca-a-partir-de-segunda-feira-3-11/5196028913",
#     "comments": 0,
#     "error": false
#   },
#   {
#     "title": "COGEX abre novas vagas para o casamento comunit\u00e1rio de S\u00e3o Lu\u00eds 2025",
#     "url": "https://www.jusbrasil.com.br/noticias/cogex-abre-novas-vagas-para-o-casamento-comunitario-de-sao-luis-2025/5187927646",
#     "comments": 0,
#     "error": false
#   },
#   {
#     "title": "Com recorde de p\u00fablico, 7\u00aa Corrida da Justi\u00e7a une pessoas e celebra sa\u00fade, inclus\u00e3o e supera\u00e7\u00e3o em Palmas neste domingo (26/10)",
#     "url": "https://www.jusbrasil.com.br/noticias/com-recorde-de-publico-7-corrida-da-justica-une-pessoas-e-celebra-saude-inclusao-e-superacao-em-palmas-neste-domingo-26-10/5182988428",
#     "comments": 2,
#     "error": false
#   }
# ]

# %%
import os
import json
import asyncio
from typing import List
from pydantic import BaseModel, Field
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode, LLMConfig
from crawl4ai import LLMExtractionStrategy

class Entity(BaseModel):
    name: str
    description: str

class Relationship(BaseModel):
    entity1: Entity
    entity2: Entity
    description: str
    relation_type: str

class KnowledgeGraph(BaseModel):
    entities: List[Entity]
    relationships: List[Relationship]

async def main():
    # LLM extraction strategy
    llm_strat = LLMExtractionStrategy(
        llmConfig = LLMConfig(provider="ollama/llama3.2", base_url="http://localhost:11434"),
        schema=KnowledgeGraph.model_json_schema(),
        extraction_type="schema",
        instruction="Extract entities and relationships from the content. Return valid JSON.",
        chunk_token_threshold=1400,
        apply_chunking=True,
        input_format="html",
        extra_args={"temperature": 0.1, "max_tokens": 2000}
    )

    crawl_config = CrawlerRunConfig(
        extraction_strategy=llm_strat,
        cache_mode=CacheMode.BYPASS
    )

    async with AsyncWebCrawler(config=BrowserConfig(headless=True)) as crawler:
        # Example page
        url = "https://www.jusbrasil.com.br/noticias/"
        result = await crawler.arun(url=url, config=crawl_config)

        print("--- LLM RAW RESPONSE ---")
        print(result.extracted_content)
        print("--- END LLM RAW RESPONSE ---")

        if result.success:
            with open("kb_result.json", "w", encoding="utf-8") as f:
                f.write(result.extracted_content)
            llm_strat.show_usage()
        else:
            print("Crawl failed:", result.error_message)

# %%
await main()
# Out:
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 4.48s
# [SCRAPE].. ◆ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 0.21s
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# [EXTRACT]. ■ https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 9.69s
# [COMPLETE] ● https://www.jusbrasil.com.br/noticias/                                                               |
# ✓ | ⏱: 14.40s
# --- LLM RAW RESPONSE ---
# [
#     {
#         "index": 0,
#         "error": true,
#         "tags": [
#             "error"
#         ],
#         "content": "litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     },
#     {
#         "index": 1,
#         "error": true,
#         "tags": [
#             "error"
#         ],
#         "content": "litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     },
#     {
#         "index": 2,
#         "error": true,
#         "tags": [
#             "error"
#         ],
#         "content": "litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     },
#     {
#         "index": 3,
#         "error": true,
#         "tags": [
#             "error"
#         ],
#         "content": "litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     },
#     {
#         "index": 4,
#         "error": true,
#         "tags": [
#             "error"
#         ],
#         "content": "litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     },
#     {
#         "index": 5,
#         "error": true,
#         "tags": [
#             "error"
#         ],
#         "content": "litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     },
#     {
#         "index": 6,
#         "error": true,
#         "tags": [
#             "error"
#         ],
#         "content": "litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     }
# ]
# --- END LLM RAW RESPONSE ---
#
# === Token Usage Summary ===
# Type                   Count
# ------------------------------
# Completion                 0
# Prompt                     0
# Total                      0
#
# === Usage History ===
# Request #    Completion       Prompt        Total
# ------------------------------------------------

# %%
import os
import asyncio
from typing import List
from dotenv import load_dotenv, find_dotenv

# Importações das ferramentas solicitadas
from tavily import TavilyClient
from crawl4ai import AsyncWebCrawler

# Carrega variáveis de ambiente
load_dotenv(find_dotenv())

# Configuração de Arquivo de Saída
OUTPUT_FILE = "predictus_knowledge_base.md"

def search_tavily(query: str, max_results: int = 5) -> List[str]:
    """
    Realiza a busca no Tavily e retorna uma lista de URLs.
    """
    api_key = os.getenv("TAVILY_API_KEY")
    if not api_key:
        raise ValueError("A chave TAVILY_API_KEY não foi encontrada no arquivo .env")

    print(f"Iniciando pesquisa Tavily para: '{query}'...")
    
    tavily_client = TavilyClient(api_key=api_key)
    
    # search_depth="advanced" garante resultados mais profundos e de melhor qualidade
    response = tavily_client.search(
        query=query, 
        search_depth="advanced", 
        max_results=max_results
    )
    
    urls = [result['url'] for result in response.get('results', [])]
    
    print(f"✅ Encontradas {len(urls)} URLs relevantes.")
    return urls

# %%
async def crawl_and_save(urls: List[str]):
    """
    Recebe lista de URLs, extrai Markdown via Crawl4AI em paralelo e salva em arquivo.
    """
    if not urls:
        print("⚠️ Nenhuma URL para processar.")
        return

    print("Iniciando Deep Crawling com Crawl4AI...")
    
    async with AsyncWebCrawler() as crawler:
        results = await crawler.arun_many(urls)
        
        print(f"Gravando resultados em {OUTPUT_FILE}...")
        
        with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
            # Cabeçalho do Arquivo
            f.write(f"# Base de Conhecimento: Predictus\n")
            f.write(f"Gerado automaticamente via Tavily + Crawl4AI\n\n")
            
            for result in results:
                if result.success:
                    # Formatação visual para separar as fontes no arquivo final
                    f.write(f"\n{'='*40}\n")
                    f.write(f"FONTE: {result.url}\n")
                    f.write(f"{'='*40}\n\n")
                    
                    # O conteúdo Markdown limpo gerado pelo Crawl4AI
                    f.write(result.markdown)
                    
                    print(f"  -> Sucesso: {result.url}")
                else:
                    print(f"  -> Falha ao ler: {result.url} | Erro: {result.error_message}")

# %%
async def main():
    # 1. Definição da Query
    # Focamos em "Soluções" e "Produtos" para pegar o core business da empresa
    query = "Predictus empresa soluções de tecnologia para o setor jurídico no Brasil."
    
    # 2. Busca (Tavily)
    try:
        urls = search_tavily(query, max_results=10)
    except Exception as e:
        print(f"Erro fatal na busca: {e}")
        return

    # 3. Extração e Gravação (Crawl4AI)
    if urls:
        await crawl_and_save(urls)
        print("\n🎉 Processo finalizado com sucesso!")

# %%
await main()
# Out:
# Iniciando pesquisa Tavily para: 'Predictus empresa soluções de tecnologia para o setor jurídico no Brasil.'...
# ✅ Encontradas 2 URLs relevantes.
# 🚀 Iniciando processamento em BATCH de 2 URLs...
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 2.09s
# [SCRAPE].. ◆ https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 0.03s
# [EXTRACT]. ■ https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 0.03s
# [COMPLETE] ● https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 2.17s
# [FETCH]... ↓ https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 2.57s
# [SCRAPE].. ◆ https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 0.06s
# [EXTRACT]. ■ https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 0.03s
# [COMPLETE] ● https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 2.67s
# ✅ Sucesso: https://centraldodireito.com.br/noticias/predictus-apresenta-novas-solucoes-de-analise-juridica-com-ia-na-fenalaw-2025
# ✅ Sucesso: https://inforchannel.com.br/2025/04/23/predictus-lanca-software-capaz-de-prever-resultados-de-processos-judiciais/
#
# 📊 Total de produtos extraídos: 2
# 💾 Arquivo 'batch_products_extracted.json' salvo com sucesso.

# %%
import os
import asyncio
import json
from typing import List
from dotenv import load_dotenv
from pydantic import BaseModel, Field

from crawl4ai import AsyncWebCrawler, CrawlerRunConfig, CacheMode, LLMConfig
from crawl4ai.extraction_strategy import LLMExtractionStrategy
from crawl4ai.markdown_generation_strategy import DefaultMarkdownGenerator

load_dotenv()

# 1. O Schema (O Contrato de Dados)
class ProductInfo(BaseModel):
    product_name: str = Field(..., description="Nome do produto ou solução.")
    summary: str = Field(..., description="Resumo breve do que o produto faz.")
    key_features: List[str] = Field(..., description="Lista dos principais diferenciais.")

# 2. A Configuração Mestra (Reuse Configuration)
# Criamos a configuração UMA vez e aplicamos a TODAS as URLs do lote.
def get_crawler_config():
    # A. Limpeza Visual (Tira imagens e links)
    md_generator = DefaultMarkdownGenerator(
        options={
            "ignore_images": True,
            "ignore_links": True,
            "escape_html": True
        }
    )

    # B. Estratégia de Inteligência (Extrai JSON)
    llm_strategy = LLMExtractionStrategy(
        llm_config=LLMConfig(
            provider="openai/gpt-4o-mini", # Use mini para batch (mais barato e rápido)
            api_token=os.getenv("OPENAI_API_KEY"),
        ),
        schema=ProductInfo.model_json_schema(),
        extraction_type="schema",
        instruction="Extraia informações sobre produtos. Se não houver produtos, retorne null."
    )

    # C. Objeto de Configuração
    return CrawlerRunConfig(
        cache_mode=CacheMode.BYPASS,
        markdown_generator=md_generator,
        extraction_strategy=llm_strategy,
        exclude_external_links=True,
        remove_overlay_elements=True,
        word_count_threshold=10
    )

async def process_batch_urls(urls: List[str]):
    print(f"🚀 Iniciando processamento em BATCH de {len(urls)} URLs...")
    
    # Instanciamos a config
    batch_config = get_crawler_config()

    async with AsyncWebCrawler() as crawler:
        # --- A MÁGICA ACONTECE AQUI ---
        # Passamos a lista de URLs e a mesma config para todas.
        # O Crawl4AI gerencia a concorrência internamente.
        results = await crawler.arun_many(
            urls=urls,
            config=batch_config 
        )

        processed_data = []

        # Iteramos sobre os resultados (que voltam na mesma ordem da lista)
        for result in results:
            if result.success:
                print(f"✅ Sucesso: {result.url}")
                try:
                    # O conteúdo extraído é uma string JSON. Convertemos para dict.
                    data = json.loads(result.extracted_content)
                    
                    # Às vezes o LLM retorna uma lista de produtos por página, às vezes um objeto.
                    # Normalizamos para garantir estrutura.
                    if isinstance(data, list):
                        for item in data:
                            item['source_url'] = result.url # Rastreabilidade
                            processed_data.append(item)
                    else:
                        data['source_url'] = result.url
                        processed_data.append(data)
                        
                except json.JSONDecodeError:
                    print(f"⚠️ Aviso: LLM não retornou JSON válido para {result.url}")
            else:
                print(f"❌ Falha ao acessar {result.url}: {result.error_message}")

        return processed_data


async def main():
    # Lista de URLs para teste (Simulando o retorno do Tavily)
    query = "Predictus empresa soluções de tecnologia para o setor jurídico no Brasil."
    
    try:
        urls = search_tavily(query, max_results=2)
    except Exception as e:
        print(f"Erro fatal na busca: {e}")
        return

    all_products = await process_batch_urls(urls)

    if all_products:
        print(f"\n📊 Total de produtos extraídos: {len(all_products)}")
        
        # Salvando o resultado consolidado
        with open("batch_products_extracted.json", "w", encoding="utf-8") as f:
            json.dump(all_products, f, indent=2, ensure_ascii=False)
            print("💾 Arquivo 'batch_products_extracted.json' salvo com sucesso.")

await main()
# Out:
# Iniciando pesquisa Tavily para: 'Predictus empresa soluções de tecnologia para o setor jurídico no Brasil.'...
# ✅ Encontradas 2 URLs relevantes.
# 🚀 Iniciando processamento em BATCH de 2 URLs...
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 1.88s
# [SCRAPE].. ◆ https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 0.02s
# [FETCH]... ↓ https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 3.35s
# [SCRAPE].. ◆ https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 0.08s
# [EXTRACT]. ■ https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 4.59s
# [COMPLETE] ● https://inforchannel.com.br/2025/04/23/predictus...paz-de-prever-resultados-de-processos-judiciais/  |
# ✓ | ⏱: 8.03s
# [EXTRACT]. ■ https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 7.30s
# [COMPLETE] ● https://centraldodireito.com.br/noticias/predict...ucoes-de-analise-juridica-com-ia-na-fenalaw-2025  |
# ✓ | ⏱: 9.22s
# ✅ Sucesso: https://inforchannel.com.br/2025/04/23/predictus-lanca-software-capaz-de-prever-resultados-de-processos-judiciais/
# ✅ Sucesso: https://centraldodireito.com.br/noticias/predictus-apresenta-novas-solucoes-de-analise-juridica-com-ia-na-fenalaw-2025
#
# 📊 Total de produtos extraídos: 4
# 💾 Arquivo 'batch_products_extracted.json' salvo com sucesso.

# %% [markdown]
# ## Teste de extração de produtos Predictus

# %%
import os
import json
from typing import List
from dotenv import load_dotenv, find_dotenv
from pydantic import BaseModel, Field

from crawl4ai import AsyncWebCrawler, CrawlerRunConfig, CacheMode, LLMConfig
from crawl4ai.extraction_strategy import LLMExtractionStrategy
from crawl4ai.markdown_generation_strategy import DefaultMarkdownGenerator

load_dotenv(find_dotenv())
# Out:
# True

# %%
# 1. O Schema (O Contrato de Dados)
class ProductInfo(BaseModel):
    product_name: str = Field(..., description="Nome do produto ou solução.")
    summary: str = Field(..., description="Resumo breve do que o produto faz.")
    key_features: List[str] = Field(..., description="Lista dos principais diferenciais.")

# %%
async def extract_clean_products(urls: List[str]):

    md_generator = DefaultMarkdownGenerator(
        options={
            "ignore_images": True,
            "ignore_links": True,
            "escape_html": True
        }
    )

    llm_strategy = LLMExtractionStrategy(
        llm_config=LLMConfig(
            # provider="groq/llama-3.3-70b-versatile",
            # api_token=os.getenv("GROQ_API_KEY"),
            provider="openai/gpt-4o-mini",
            api_token=os.getenv("OPENAI_API_KEY"),
            temperature=0
        ),
        schema=ProductInfo.model_json_schema(), # Passamos o esquema definido acima
        extraction_type="schema",
        instruction=(
            "Analise o conteúdo da página e extraia informações APENAS sobre "
            "produtos, serviços ou soluções de software oferecidos pela empresa. "
            "Ignore histórico da empresa, notícias, vagas de emprego ou rodapés."
        )
    )

    # 4. Configuração da Execução
    crawl_config = CrawlerRunConfig(
        cache_mode=CacheMode.BYPASS, # Para garantir dados frescos
        markdown_generator=md_generator, # Aplica a limpeza visual
        extraction_strategy=llm_strategy, # Aplica a inteligência
        word_count_threshold=10, # Ignora blocos de texto muito curtos (menus, botões)
        exclude_external_links=True, # Não segue links para fora
        remove_overlay_elements=True # Remove popups de cookies/chat
    )

    async with AsyncWebCrawler() as crawler:
        results = await crawler.arun_many(
            urls=urls,
            config=crawl_config
        )

        processed_data = []
        for result in results:
            if result.success:
                try:
                    data = json.loads(result.extracted_content)

                    if isinstance(data, list):
                        for item in data:
                            item['source_url'] = result.url
                            processed_data.append(item)
                    else:
                        data['source_url'] = result.url
                        processed_data.append(data)
                        
                except json.JSONDecodeError:
                    print(f"⚠️ Aviso: LLM não retornou JSON válido para {result.url}")
            else:
                print(f"❌ Falha ao acessar {result.url}: {result.error_message}")

        return processed_data

# %%
async def main():
    urls = [
        "https://predictus.inf.br/predictus_plataforma/",
        "https://predictus.inf.br/predictus-api/",
        "https://predictus.inf.br/predictus_jurimetria/"
    ]

    products_container = await extract_clean_products(urls)

    if products_container:
        with open("./tmp/predictus_products_clean.json", "w", encoding="utf-8") as f:
            json.dump(products_container, f, indent=2, ensure_ascii=False)


products_container = await main()
# Out:
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 7.49s
# [SCRAPE].. ◆ https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 0.16s
# [FETCH]... ↓ https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 8.04s
# [SCRAPE].. ◆ https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 0.15s
# [FETCH]... ↓ https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 8.44s
# [SCRAPE].. ◆ https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 0.15s
# [EXTRACT]. ■ https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 6.26s
# [COMPLETE] ● https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 14.47s
# [EXTRACT]. ■ https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 7.24s
# [COMPLETE] ● https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 15.84s
# [EXTRACT]. ■ https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 12.36s
# [COMPLETE] ● https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 20.03s

# %%
products = [product[0] for product in products_container]

# %% [markdown]
# ## Workflow LangGraph - Extração, Dossiê e Prompt Template
#
# Este workflow automatiza:
# 1. **Extração de Produtos**: Extrai informações de produtos das URLs
# 2. **Geração de Dossiê**: Cria um dossiê completo usando LLM
# 3. **Criação de Prompt Template**: Gera um template de prompt com contexto dos produtos

# %%
# Imports para LangGraph
from typing import TypedDict, List, Annotated
from pathlib import Path
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
import operator

# Definindo o State do workflow
class WorkflowState(TypedDict):
    """Estado compartilhado entre os nodes do workflow"""
    urls: List[str]  # URLs para extrair produtos
    extracted_products: List[dict]  # Produtos extraídos (lista de JSON)
    dossier: str  # Dossiê completo gerado pela LLM
    prompt_template: str  # Template de prompt final com contexto
# Out:
# /home/gabriel/Documentos/Projetos_Python/Projeto_Crawler_Juridico/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
# Node 1: Extração de Produtos (assíncrono)
async def extract_products_node(state: WorkflowState) -> WorkflowState:
    """
    Node assíncrono que extrai informações de produtos das URLs fornecidas.
    Usa o código de extração existente.
    """
    print("🔍 [Node 1] Iniciando extração de produtos...")
    
    urls = state.get("urls", [])
    if not urls:
        print("⚠️ Nenhuma URL fornecida")
        return {**state, "extracted_products": []}
    
    # Usa a função extract_clean_products já definida
    extracted_products = await extract_clean_products(urls)
    
    print(f"✅ [Node 1] Extraídos {len(extracted_products)} produtos de {len(urls)} URLs")
    
    return {
        **state,
        "extracted_products": extracted_products
    }

# %%
# Node 2: Geração de Dossiê (assíncrono)
async def generate_dossier_node(state: WorkflowState) -> WorkflowState:
    """
    Node assíncrono que gera um dossiê completo das soluções da empresa
    usando os produtos extraídos.
    """
    print("📝 [Node 2] Gerando dossiê completo...")
    
    extracted_products = state.get("extracted_products", [])
    
    if not extracted_products:
        print("⚠️ Nenhum produto extraído para gerar dossiê")
        return {**state, "dossier": "Nenhum produto encontrado."}
    
    # Prepara o contexto dos produtos
    products_context = json.dumps(extracted_products, indent=2, ensure_ascii=False)
    
    # Configura o LLM
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0.3,
        api_key=os.getenv("OPENAI_API_KEY")
    )
    
    # Prompt para gerar o dossiê
    system_prompt = """Você é um analista especializado em documentação de produtos e soluções tecnológicas.
    Sua tarefa é criar um dossiê completo e profissional sobre as soluções oferecidas pela empresa. Verifique
    SEMPRE se um produto que já foi abordado está sendo mecionado novamente e caso tiver uma correspondência de 
    70% de similaridade mantenha somente uma versão do produto.
    EX: 
     - Predictus Jurimetria == Jurimetria: previsões baseadas em dados judiciais
     - Predictus Plataforma == Plataforma Web Predictus
    """
    
    user_prompt = f"""Com base nas informações dos produtos extraídos abaixo, crie um dossiê completo e detalhado 
    sobre as soluções oferecidas pela empresa Predictus.

    O dossiê deve incluir:
    1. Visão geral da empresa e seu portfólio
    2. Descrição detalhada de cada solução/produto (deduplicada)
    3. Diferenciais competitivos
    4. Casos de uso e aplicações
    5. Resumo executivo

    Informações dos produtos:
    {products_context}

    Gere um dossiê profissional, bem estruturado e completo."""
    
    # Gera o dossiê
    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=user_prompt)
    ]
    
    response = await llm.ainvoke(messages)
    dossier = response.content
    
    print(f"✅ [Node 2] Dossiê gerado com sucesso ({len(dossier)} caracteres)")
    
    return {
        **state,
        "dossier": dossier
    }

# %%
# Node 3: Criação de Prompt Template (assíncrono)
async def create_prompt_template_node(state: WorkflowState) -> WorkflowState:
    """
    Node assíncrono que cria um template de prompt com o contexto dos produtos
    e o dossiê gerado.
    """
    print("📋 [Node 3] Criando prompt template...")
    
    extracted_products = state.get("extracted_products", [])
    dossier = state.get("dossier", "")
    
    # Prepara o contexto dos produtos em formato JSON
    products_json = json.dumps(extracted_products, indent=2, ensure_ascii=False)
    
    # Cria o template de prompt
    prompt_template = f"""# Contexto da Empresa: Predictus

        ## Dossiê Completo das Soluções

        {dossier}

        ## Produtos e Soluções (JSON)

        ```json
        {products_json}
        ```

        ## Instruções

        Use o contexto acima para responder perguntas sobre:
        - Produtos e soluções oferecidos pela Predictus
        - Características e funcionalidades de cada solução
        - Casos de uso e aplicações
        - Diferenciais competitivos

        Seja preciso e use as informações do contexto fornecido.
    """
    
    print(f"✅ [Node 3] Prompt template criado com sucesso ({len(prompt_template)} caracteres)")
    
    return {
        **state,
        "prompt_template": prompt_template
    }

# %%
# Criação do Grafo LangGraph
def create_workflow_graph():
    """
    Cria e retorna o grafo do workflow LangGraph.
    """
    # Cria o grafo
    workflow = StateGraph(WorkflowState)
    
    # Adiciona os nodes
    workflow.add_node("extract_products", extract_products_node)
    workflow.add_node("generate_dossier", generate_dossier_node)
    workflow.add_node("create_prompt_template", create_prompt_template_node)
    
    # Define o fluxo: START -> extract -> generate -> create -> END
    workflow.add_edge(START, "extract_products")
    workflow.add_edge("extract_products", "generate_dossier")
    workflow.add_edge("generate_dossier", "create_prompt_template")
    workflow.add_edge("create_prompt_template", END)
    
    # Compila o grafo
    app = workflow.compile()
    
    return app

# Cria o grafo
workflow_app = create_workflow_graph()

print("✅ Workflow LangGraph criado com sucesso!")
print("   Fluxo: START -> Extração -> Dossiê -> Prompt Template -> END")
# Out:
# ✅ Workflow LangGraph criado com sucesso!
#    Fluxo: START -> Extração -> Dossiê -> Prompt Template -> END

# %%
# Função para executar o workflow completo
async def run_workflow(urls: List[str]) -> dict:
    """
    Executa o workflow completo com as URLs fornecidas.
    
    Args:
        urls: Lista de URLs para extrair produtos
        
    Returns:
        Estado final do workflow com todos os resultados
    """
    print("🚀 Iniciando workflow LangGraph...")
    print(f"   URLs: {len(urls)}")
    print("-" * 60)
    
    # Estado inicial
    initial_state: WorkflowState = {
        "urls": urls,
        "extracted_products": [],
        "dossier": "",
        "prompt_template": ""
    }
    
    # Executa o workflow
    final_state = await workflow_app.ainvoke(initial_state)
    
    print("-" * 60)
    print("✅ Workflow concluído com sucesso!")
    
    return final_state

# Exemplo de uso:
# urls = [
#     "https://predictus.inf.br/predictus_plataforma/",
#     "https://predictus.inf.br/predictus-api/",
#     "https://predictus.inf.br/predictus_jurimetria/"
# ]
# result = await run_workflow(urls)

# %%
# Executar o workflow completo
urls_to_process = [
    "https://predictus.inf.br/predictus_plataforma/",
    "https://predictus.inf.br/predictus-api/",
    "https://predictus.inf.br/predictus_jurimetria/"
]

# Executa o workflow
workflow_result = await run_workflow(urls_to_process)

# Exibe os resultados
print("\n" + "="*60)
print("📊 RESULTADOS DO WORKFLOW")
print("="*60)

print(f"\n✅ Produtos extraídos: {len(workflow_result['extracted_products'])}")
print(f"✅ Dossiê gerado: {len(workflow_result['dossier'])} caracteres")
print(f"✅ Prompt template: {len(workflow_result['prompt_template'])} caracteres")

# Salva os resultados
output_dir = Path("./tmp")
output_dir.mkdir(exist_ok=True)

# Salva produtos extraídos
with open(output_dir / "workflow_products.json", "w", encoding="utf-8") as f:
    json.dump(workflow_result['extracted_products'], f, indent=2, ensure_ascii=False)

# Salva dossiê
with open(output_dir / "workflow_dossier.md", "w", encoding="utf-8") as f:
    f.write(workflow_result['dossier'])

# Salva prompt template
with open(output_dir / "workflow_prompt_template.md", "w", encoding="utf-8") as f:
    f.write(workflow_result['prompt_template'])

print(f"\n💾 Arquivos salvos em: {output_dir}")
print("   - workflow_products.json")
print("   - workflow_dossier.md")
print("   - workflow_prompt_template.md")
# Out:
# 🚀 Iniciando workflow LangGraph...
#    URLs: 3
# ------------------------------------------------------------
# 🔍 [Node 1] Iniciando extração de produtos...
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 6.32s
# [SCRAPE].. ◆ https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 0.15s
# [FETCH]... ↓ https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 6.91s
# [SCRAPE].. ◆ https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 0.21s
# [FETCH]... ↓ https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 9.04s
# [SCRAPE].. ◆ https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 0.12s
# [EXTRACT]. ■ https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 4.34s
# [COMPLETE] ● https://predictus.inf.br/predictus_plataforma/                                                       |
# ✓ | ⏱: 10.83s
# [EXTRACT]. ■ https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 7.78s
# [COMPLETE] ● https://predictus.inf.br/predictus_jurimetria/                                                       |
# ✓ | ⏱: 14.94s
# [EXTRACT]. ■ https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 11.54s
# [COMPLETE] ● https://predictus.inf.br/predictus-api/                                                              |
# ✓ | ⏱: 20.72s
# ✅ [Node 1] Extraídos 11 produtos de 3 URLs
# 📝 [Node 2] Gerando dossiê completo...
# ✅ [Node 2] Dossiê gerado com sucesso (6751 caracteres)
# 📋 [Node 3] Criando prompt template...
# ✅ [Node 3] Prompt template criado com sucesso (12787 caracteres)
# ------------------------------------------------------------
# ✅ Workflow concluído com sucesso!
#
# ============================================================
# 📊 RESULTADOS DO WORKFLOW
# ============================================================
#
# ✅ Produtos extraídos: 11
# ✅ Dossiê gerado: 6751 caracteres
# ✅ Prompt template: 12787 caracteres
#
# 💾 Arquivos salvos em: tmp
#    - workflow_products.json
#    - workflow_dossier.md
#    - workflow_prompt_template.md

# %%
# Visualizar o dossiê gerado
print("="*60)
print("📄 DOSSIÊ GERADO")
print("="*60)
print(workflow_result['dossier'])
# Out:
# ============================================================
# 📄 DOSSIÊ GERADO
# ============================================================
# # Dossiê de Soluções da Predictus
#
# ## 1. Visão Geral da Empresa e seu Portfólio
#
# A Predictus é uma empresa inovadora que se destaca no mercado de tecnologia jurídica, oferecendo soluções que transformam dados judiciais em insights valiosos para advogados, departamentos jurídicos e instituições financeiras. Com um portfólio diversificado, a Predictus disponibiliza ferramentas que vão desde análises preditivas até integrações de dados, permitindo que seus clientes tomem decisões informadas e estratégicas.
#
# ### Portfólio de Produtos
# - **Predictus Jurimetria**
# - **Plataforma Web Predictus**
# - **API Predictus**
# - **Análise de crédito e risco**
# - **Diligência e análise detalhada de processos via CNJ**
# - **Análise e benchmarking de advogados**
# - **Consulta customizada de processos via filtros**
# - **Jurimetria: previsões baseadas em dados judiciais**
# - **Integrações simples e poderosas**
# - **Predictus Plataforma**
# - **Consultas para Análise de Crédito e Risco**
# - **Acompanhamento de Processos**
# - **Avaliação Judicial para NPLs e Ativos Estressados**
# - **Análise Processual para Locação Segura de Imóveis**
# - **Consultas Judiciais para Compliance**
# - **Busca de Leads para Aquisição de Ativos Judiciais**
# - **Homologação de Fornecedores**
# - **Gerenciamento de Riscos no Transporte de Cargas**
# - **Análise Judicial para Recrutamento e Seleção**
#
# ## 2. Descrição Detalhada de Cada Solução/Produto
#
# ### Predictus Jurimetria
# Um módulo de análise preditiva que transforma milhões de processos judiciais em insights estratégicos, permitindo que advogados e departamentos jurídicos prevejam desfechos e tomem decisões informadas.
# - **Características Principais**:
#   - Análise preditiva baseada em dados reais de mais de 700 milhões de processos judiciais.
#   - Cobertura nacional com dados de mais de 90 tribunais brasileiros.
#   - Atualização contínua e automática com mais de 1 milhão de atualizações por dia.
#   - Resultados em até 3 segundos com visualização simplificada.
#   - Interface prática e fácil de usar.
# - **[Mais informações](https://predictus.inf.br/predictus_jurimetria/)**
#
# ### Plataforma Web Predictus
# Acesso a dados diretamente do navegador, permitindo consultas rápidas e intuitivas sobre processos judiciais.
# - **Características Principais**:
#   - Consulta por CPF, CNPJ, OAB ou número CNJ.
#   - Visualização intuitiva de processos.
#   - Painel com insights preditivos.
#   - Organização automática das partes, classe, assunto, instância e vara.
# - **[Mais informações](https://predictus.inf.br/predictus_jurimetria/)**
#
# ### API Predictus
# Integração de dados aos sistemas internos, permitindo automação de consultas e personalização de fluxos de trabalho.
# - **Características Principais**:
#   - Automatização de consultas e filtros em escala.
#   - Leitura padronizada de decisões e históricos.
#   - Otimização de análise de risco, compliance, credit scoring e due diligence.
# - **[Mais informações](https://predictus.inf.br/predictus_jurimetria/)**
#
# ### Análise de Crédito e Risco
# Fornece todos os processos judiciais vinculados a um CPF/CNPJ ou nome, retornando resultados em menos de 3 segundos.
# - **Características Principais**:
#   - Ideal para análise de crédito e risco, KYC, background check e due diligence.
#   - Acesso instantâneo a informações cruciais.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Diligência e Análise Detalhada de Processos via CNJ
# Acesso a informações detalhadas sobre qualquer processo judicial utilizando apenas o número CNJ.
# - **Características Principais**:
#   - Informações precisas para avaliação completa.
#   - Essencial para diligência e análise específica de casos.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Análise e Benchmarking de Advogados
# Consulta por OAB para acessar todos os processos judiciais em que um advogado específico representa uma das partes.
# - **Características Principais**:
#   - Ideal para benchmarking e análise detalhada de carteiras de advogados.
#   - Insights valiosos sobre a atuação jurídica.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Consulta Customizada de Processos via Filtros
# Permite personalizar a busca por processos judiciais usando filtros específicos.
# - **Características Principais**:
#   - Ideal para busca de leads, precedentes jurídicos e modelagem de dados.
#   - Resultados precisos e adaptados às necessidades de análise.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Jurimetria: Previsões Baseadas em Dados Judiciais
# Consulta de jurimetria para obter previsões baseadas em estudos estatísticos de processos similares.
# - **Características Principais**:
#   - Dados cruciais sobre os possíveis desfechos de um caso.
#   - Ajuda na preparação processual e estratégia legal.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Integrações Simples e Poderosas
# Integra dados de processos judiciais a diversos sistemas existentes na organização.
# - **Características Principais**:
#   - Definição de regras de negócio.
#   - Automatização de fluxos de decisão.
#   - APIs projetadas para se adequarem à operação.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Predictus Plataforma
# Plataforma web que democratiza o acesso a dados de processos judiciais, permitindo consultas instantâneas em nível nacional diretamente do navegador.
# - **Características Principais**:
#   - Consultas instantâneas de processos judiciais.
#   - Dados organizados e estruturados sem necessidade de integração.
#   - Facilidade de compreensão e download das informações.
#   - Ideal para usuários B2B.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Consultas para Análise de Crédito e Risco
# Permite que instituições financeiras acessem o histórico judicial de potenciais clientes para identificar comportamentos de risco.
# - **Características Principais**:
#   - Identificação de inadimplência e antecedentes criminais.
#   - Acesso a dados judiciais relevantes para análise de crédito.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Acompanhamento de Processos
# Facilita o acompanhamento de ações judiciais próprias de empresas através da busca periódica pelo CNPJ.
# - **Características Principais**:
#   - Identificação rápida de processos recém distribuídos.
#   - Ideal para departamentos jurídicos.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Avaliação Judicial para NPLs e Ativos Estressados
# Utiliza consultas de processos judiciais para avaliar ativos e passivos de devedores, proporcionando uma visão ampla do risco.
# - **Características Principais**:
#   - Avaliação de ativos inadimplidos.
#   - Informações detalhadas sobre a situação judicial dos devedores.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Análise Processual para Locação Segura de Imóveis
# Auxilia garantidoras de aluguel na avaliação de riscos de potenciais clientes através da consulta de processos.
# - **Características Principais**:
#   - Verificação de ações de despejo e inadimplência.
#   - Proteção contra prejuízos para empresas e proprietários.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Consultas Judiciais para Compliance
# Potencializa o background check e a due diligence com consultas instantâneas de processos judiciais.
# - **Características Principais**:
#   - Investigação do histórico judicial de empresas e colaboradores.
#   - Acesso a dados detalhados de antecedentes criminais, cíveis e trabalhistas.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Busca de Leads para Aquisição de Ativos Judiciais
# Permite encontrar leads através de processos judiciais, potencializando a geração de demanda.
# - **Características Principais**:
#   - Filtros de busca personalizados.
#   - Informações detalhadas sobre ações judiciais.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Homologação de Fornecedores
# Consulta a situação judicial de fornecedores para identificar riscos associados.
# - **Características Principais**:
#   - Acesso a informações criminais, cíveis e trabalhistas.
#   - Garantia de relações saudáveis e éticas.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Gerenciamento de Riscos no Transporte de Cargas
# Consulta criminal para garantir a conformidade legal no transporte de cargas, conforme a Lei nº 13.640/2018.
# - **Características Principais**:
#   - Checagem de antecedentes do motorista.
#   - Acesso ao histórico judicial completo.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Análise Judicial para Recrutamento e Seleção
# Permite conhecer o histórico judicial de candidatos durante o processo de seleção.
# - **Características Principais**:
#   - Consulta de antecedentes criminais.
#   - Conformidade legal nas contratações.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ## 3. Diferenciais Competitivos
#
# - **Base de Dados Abrangente**: A Predictus possui acesso a mais de 700 milhões de processos judiciais, cobrindo mais de 90 tribunais brasileiros, o que proporciona uma base sólida para análises preditivas.
# - **Atualização Contínua**: Com mais de 1 milhão de atualizações diárias, as informações estão sempre atualizadas, garantindo que os usuários tenham acesso aos dados mais recentes.
# - **Interface Intuitiva**: As soluções são projetadas com foco na experiência do usuário, permitindo que tanto profissionais jurídicos quanto não jurídicos utilizem as ferramentas com facilidade.
# - **Integração e Automação**: A API da Predictus permite que as empresas integrem dados judiciais em seus sistemas internos, otimizando fluxos de trabalho e aumentando a eficiência operacional.
# - **Teste Grátis**: A empresa oferece testes gratuitos de várias soluções, permitindo que os clientes experimentem os produtos antes de tomar uma decisão de compra.
#
# ## 4. Casos de Uso e Aplicações
#
# - **Advocacia**: Advogados podem utilizar a Predictus Jurimetria para prever desfechos de casos e desenvolver estratégias legais mais eficazes.
# - **Instituições Financeiras**: As soluções de análise de crédito e risco permitem que bancos e financeiras realizem uma avaliação mais precisa do histórico judicial de potenciais clientes.
# - **Compliance e Due Diligence**: Empresas podem usar as consultas judiciais para verificar antecedentes de colaboradores e fornecedores, garantindo conformidade legal.
# - **Gestão de Risco**: Organizações podem monitorar a situação judicial de seus fornecedores e clientes, minimizando riscos associados a inadimplência e litígios.
# - **Recrutamento**: As ferramentas de análise judicial para recrutamento ajudam as empresas a garantir que estão contratando candidatos com histórico limpo.
#
# ## 5. Resumo Executivo
#
# A Predictus se posiciona como uma líder no setor de tecnologia jurídica, oferecendo soluções inovadoras que transformam dados judiciais em insights estratégicos. Com um portfólio robusto que abrange desde análises preditivas até integrações de sistemas, a empresa atende a uma ampla gama de clientes, incluindo advogados, departamentos jurídicos e instituições financeiras. Seus diferenciais competitivos, como uma base de dados abrangente, atualização contínua e uma interface intuitiva, garantem que os usuários possam tomar decisões informadas e eficazes. A Predictus não apenas democratiza o acesso a dados judiciais, mas também potencializa a eficiência e a segurança nas operações de seus clientes, consolidando-se como uma parceira essencial no cenário jurídico atual.

# %%
# Visualizar o prompt template criado
print("="*60)
print("📋 PROMPT TEMPLATE CRIADO")
print("="*60)
print(workflow_result['prompt_template'])
# Out:
# ============================================================
# 📋 PROMPT TEMPLATE CRIADO
# ============================================================
# # Contexto da Empresa: Predictus
#
#         ## Dossiê Completo das Soluções
#
#         # Dossiê de Soluções da Predictus
#
# ## 1. Visão Geral da Empresa e seu Portfólio
#
# A Predictus é uma empresa inovadora que se destaca no mercado de tecnologia jurídica, oferecendo soluções que transformam dados judiciais em insights valiosos para advogados, departamentos jurídicos e instituições financeiras. Com um portfólio diversificado, a Predictus disponibiliza ferramentas que vão desde análises preditivas até integrações de dados, permitindo que seus clientes tomem decisões informadas e estratégicas.
#
# ### Portfólio de Produtos
# - **Predictus Jurimetria**
# - **Plataforma Web Predictus**
# - **API Predictus**
# - **Análise de crédito e risco**
# - **Diligência e análise detalhada de processos via CNJ**
# - **Análise e benchmarking de advogados**
# - **Consulta customizada de processos via filtros**
# - **Jurimetria: previsões baseadas em dados judiciais**
# - **Integrações simples e poderosas**
# - **Predictus Plataforma**
# - **Consultas para Análise de Crédito e Risco**
# - **Acompanhamento de Processos**
# - **Avaliação Judicial para NPLs e Ativos Estressados**
# - **Análise Processual para Locação Segura de Imóveis**
# - **Consultas Judiciais para Compliance**
# - **Busca de Leads para Aquisição de Ativos Judiciais**
# - **Homologação de Fornecedores**
# - **Gerenciamento de Riscos no Transporte de Cargas**
# - **Análise Judicial para Recrutamento e Seleção**
#
# ## 2. Descrição Detalhada de Cada Solução/Produto
#
# ### Predictus Jurimetria
# Um módulo de análise preditiva que transforma milhões de processos judiciais em insights estratégicos, permitindo que advogados e departamentos jurídicos prevejam desfechos e tomem decisões informadas.
# - **Características Principais**:
#   - Análise preditiva baseada em dados reais de mais de 700 milhões de processos judiciais.
#   - Cobertura nacional com dados de mais de 90 tribunais brasileiros.
#   - Atualização contínua e automática com mais de 1 milhão de atualizações por dia.
#   - Resultados em até 3 segundos com visualização simplificada.
#   - Interface prática e fácil de usar.
# - **[Mais informações](https://predictus.inf.br/predictus_jurimetria/)**
#
# ### Plataforma Web Predictus
# Acesso a dados diretamente do navegador, permitindo consultas rápidas e intuitivas sobre processos judiciais.
# - **Características Principais**:
#   - Consulta por CPF, CNPJ, OAB ou número CNJ.
#   - Visualização intuitiva de processos.
#   - Painel com insights preditivos.
#   - Organização automática das partes, classe, assunto, instância e vara.
# - **[Mais informações](https://predictus.inf.br/predictus_jurimetria/)**
#
# ### API Predictus
# Integração de dados aos sistemas internos, permitindo automação de consultas e personalização de fluxos de trabalho.
# - **Características Principais**:
#   - Automatização de consultas e filtros em escala.
#   - Leitura padronizada de decisões e históricos.
#   - Otimização de análise de risco, compliance, credit scoring e due diligence.
# - **[Mais informações](https://predictus.inf.br/predictus_jurimetria/)**
#
# ### Análise de Crédito e Risco
# Fornece todos os processos judiciais vinculados a um CPF/CNPJ ou nome, retornando resultados em menos de 3 segundos.
# - **Características Principais**:
#   - Ideal para análise de crédito e risco, KYC, background check e due diligence.
#   - Acesso instantâneo a informações cruciais.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Diligência e Análise Detalhada de Processos via CNJ
# Acesso a informações detalhadas sobre qualquer processo judicial utilizando apenas o número CNJ.
# - **Características Principais**:
#   - Informações precisas para avaliação completa.
#   - Essencial para diligência e análise específica de casos.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Análise e Benchmarking de Advogados
# Consulta por OAB para acessar todos os processos judiciais em que um advogado específico representa uma das partes.
# - **Características Principais**:
#   - Ideal para benchmarking e análise detalhada de carteiras de advogados.
#   - Insights valiosos sobre a atuação jurídica.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Consulta Customizada de Processos via Filtros
# Permite personalizar a busca por processos judiciais usando filtros específicos.
# - **Características Principais**:
#   - Ideal para busca de leads, precedentes jurídicos e modelagem de dados.
#   - Resultados precisos e adaptados às necessidades de análise.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Jurimetria: Previsões Baseadas em Dados Judiciais
# Consulta de jurimetria para obter previsões baseadas em estudos estatísticos de processos similares.
# - **Características Principais**:
#   - Dados cruciais sobre os possíveis desfechos de um caso.
#   - Ajuda na preparação processual e estratégia legal.
#   - Teste grátis.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Integrações Simples e Poderosas
# Integra dados de processos judiciais a diversos sistemas existentes na organização.
# - **Características Principais**:
#   - Definição de regras de negócio.
#   - Automatização de fluxos de decisão.
#   - APIs projetadas para se adequarem à operação.
# - **[Mais informações](https://predictus.inf.br/predictus-api/)**
#
# ### Predictus Plataforma
# Plataforma web que democratiza o acesso a dados de processos judiciais, permitindo consultas instantâneas em nível nacional diretamente do navegador.
# - **Características Principais**:
#   - Consultas instantâneas de processos judiciais.
#   - Dados organizados e estruturados sem necessidade de integração.
#   - Facilidade de compreensão e download das informações.
#   - Ideal para usuários B2B.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Consultas para Análise de Crédito e Risco
# Permite que instituições financeiras acessem o histórico judicial de potenciais clientes para identificar comportamentos de risco.
# - **Características Principais**:
#   - Identificação de inadimplência e antecedentes criminais.
#   - Acesso a dados judiciais relevantes para análise de crédito.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Acompanhamento de Processos
# Facilita o acompanhamento de ações judiciais próprias de empresas através da busca periódica pelo CNPJ.
# - **Características Principais**:
#   - Identificação rápida de processos recém distribuídos.
#   - Ideal para departamentos jurídicos.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Avaliação Judicial para NPLs e Ativos Estressados
# Utiliza consultas de processos judiciais para avaliar ativos e passivos de devedores, proporcionando uma visão ampla do risco.
# - **Características Principais**:
#   - Avaliação de ativos inadimplidos.
#   - Informações detalhadas sobre a situação judicial dos devedores.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Análise Processual para Locação Segura de Imóveis
# Auxilia garantidoras de aluguel na avaliação de riscos de potenciais clientes através da consulta de processos.
# - **Características Principais**:
#   - Verificação de ações de despejo e inadimplência.
#   - Proteção contra prejuízos para empresas e proprietários.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Consultas Judiciais para Compliance
# Potencializa o background check e a due diligence com consultas instantâneas de processos judiciais.
# - **Características Principais**:
#   - Investigação do histórico judicial de empresas e colaboradores.
#   - Acesso a dados detalhados de antecedentes criminais, cíveis e trabalhistas.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Busca de Leads para Aquisição de Ativos Judiciais
# Permite encontrar leads através de processos judiciais, potencializando a geração de demanda.
# - **Características Principais**:
#   - Filtros de busca personalizados.
#   - Informações detalhadas sobre ações judiciais.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Homologação de Fornecedores
# Consulta a situação judicial de fornecedores para identificar riscos associados.
# - **Características Principais**:
#   - Acesso a informações criminais, cíveis e trabalhistas.
#   - Garantia de relações saudáveis e éticas.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Gerenciamento de Riscos no Transporte de Cargas
# Consulta criminal para garantir a conformidade legal no transporte de cargas, conforme a Lei nº 13.640/2018.
# - **Características Principais**:
#   - Checagem de antecedentes do motorista.
#   - Acesso ao histórico judicial completo.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ### Análise Judicial para Recrutamento e Seleção
# Permite conhecer o histórico judicial de candidatos durante o processo de seleção.
# - **Características Principais**:
#   - Consulta de antecedentes criminais.
#   - Conformidade legal nas contratações.
# - **[Mais informações](https://predictus.inf.br/predictus_plataforma/)**
#
# ## 3. Diferenciais Competitivos
#
# - **Base de Dados Abrangente**: A Predictus possui acesso a mais de 700 milhões de processos judiciais, cobrindo mais de 90 tribunais brasileiros, o que proporciona uma base sólida para análises preditivas.
# - **Atualização Contínua**: Com mais de 1 milhão de atualizações diárias, as informações estão sempre atualizadas, garantindo que os usuários tenham acesso aos dados mais recentes.
# - **Interface Intuitiva**: As soluções são projetadas com foco na experiência do usuário, permitindo que tanto profissionais jurídicos quanto não jurídicos utilizem as ferramentas com facilidade.
# - **Integração e Automação**: A API da Predictus permite que as empresas integrem dados judiciais em seus sistemas internos, otimizando fluxos de trabalho e aumentando a eficiência operacional.
# - **Teste Grátis**: A empresa oferece testes gratuitos de várias soluções, permitindo que os clientes experimentem os produtos antes de tomar uma decisão de compra.
#
# ## 4. Casos de Uso e Aplicações
#
# - **Advocacia**: Advogados podem utilizar a Predictus Jurimetria para prever desfechos de casos e desenvolver estratégias legais mais eficazes.
# - **Instituições Financeiras**: As soluções de análise de crédito e risco permitem que bancos e financeiras realizem uma avaliação mais precisa do histórico judicial de potenciais clientes.
# - **Compliance e Due Diligence**: Empresas podem usar as consultas judiciais para verificar antecedentes de colaboradores e fornecedores, garantindo conformidade legal.
# - **Gestão de Risco**: Organizações podem monitorar a situação judicial de seus fornecedores e clientes, minimizando riscos associados a inadimplência e litígios.
# - **Recrutamento**: As ferramentas de análise judicial para recrutamento ajudam as empresas a garantir que estão contratando candidatos com histórico limpo.
#
# ## 5. Resumo Executivo
#
# A Predictus se posiciona como uma líder no setor de tecnologia jurídica, oferecendo soluções inovadoras que transformam dados judiciais em insights estratégicos. Com um portfólio robusto que abrange desde análises preditivas até integrações de sistemas, a empresa atende a uma ampla gama de clientes, incluindo advogados, departamentos jurídicos e instituições financeiras. Seus diferenciais competitivos, como uma base de dados abrangente, atualização contínua e uma interface intuitiva, garantem que os usuários possam tomar decisões informadas e eficazes. A Predictus não apenas democratiza o acesso a dados judiciais, mas também potencializa a eficiência e a segurança nas operações de seus clientes, consolidando-se como uma parceira essencial no cenário jurídico atual.
#
#         ## Produtos e Soluções (JSON)
#
#         ```json
#         [
#   {
#     "product_name": "Predictus Jurimetria",
#     "summary": "Um módulo de análise preditiva que transforma milhões de processos judiciais em insights estratégicos, permitindo que advogados e departamentos jurídicos prevejam desfechos e tomem decisões informadas.",
#     "key_features": [
#       "Análise preditiva baseada em dados reais de mais de 700 milhões de processos judiciais.",
#       "Cobertura nacional com dados de mais de 90 tribunais brasileiros.",
#       "Atualização contínua e automática com mais de 1 milhão de atualizações por dia.",
#       "Resultados em até 3 segundos com visualização simplificada.",
#       "Interface prática e fácil de usar."
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_jurimetria/"
#   },
#   {
#     "product_name": "Plataforma Web Predictus",
#     "summary": "Acesso a dados diretamente do navegador, permitindo consultas rápidas e intuitivas sobre processos judiciais.",
#     "key_features": [
#       "Consulta por CPF, CNPJ, OAB ou número CNJ.",
#       "Visualização intuitiva de processos.",
#       "Painel com insights preditivos.",
#       "Organização automática das partes, classe, assunto, instância e vara."
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_jurimetria/"
#   },
#   {
#     "product_name": "API Predictus",
#     "summary": "Integração de dados aos sistemas internos, permitindo automação de consultas e personalização de fluxos de trabalho.",
#     "key_features": [
#       "Automatização de consultas e filtros em escala.",
#       "Leitura padronizada de decisões e históricos.",
#       "Otimização de análise de risco, compliance, credit scoring e due diligence."
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_jurimetria/"
#   },
#   {
#     "product_name": "Análise de crédito e risco",
#     "summary": "Fornece todos os processos judiciais vinculados a um CPF/CNPJ ou nome, retornando resultados em menos de 3 segundos.",
#     "key_features": [
#       "Ideal para análise de crédito e risco, KYC, background check e due diligences",
#       "Acesso instantâneo a informações cruciais",
#       "Teste grátis"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus-api/"
#   },
#   {
#     "product_name": "Diligência e análise detalhada de processos via CNJ",
#     "summary": "Acesso a informações detalhadas sobre qualquer processo judicial utilizando apenas o número CNJ.",
#     "key_features": [
#       "Informações precisas para avaliação completa",
#       "Essencial para diligência e análise específica de casos",
#       "Teste grátis"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus-api/"
#   },
#   {
#     "product_name": "Análise e benchmarking de advogados",
#     "summary": "Consulta por OAB para acessar todos os processos judiciais em que um advogado específico representa uma das partes.",
#     "key_features": [
#       "Ideal para benchmarking e análise detalhada de carteiras de advogados",
#       "Insights valiosos sobre a atuação jurídica",
#       "Teste grátis"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus-api/"
#   },
#   {
#     "product_name": "Consulta customizada de processos via filtros",
#     "summary": "Permite personalizar a busca por processos judiciais usando filtros específicos.",
#     "key_features": [
#       "Ideal para busca de leads, precedentes jurídicos e modelagem de dados",
#       "Resultados precisos e adaptados às necessidades de análise",
#       "Teste grátis"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus-api/"
#   },
#   {
#     "product_name": "Jurimetria: previsões baseadas em dados judiciais",
#     "summary": "Consulta de jurimetria para obter previsões baseadas em estudos estatísticos de processos similares.",
#     "key_features": [
#       "Dados cruciais sobre os possíveis desfechos de um caso",
#       "Ajuda na preparação processual e estratégia legal",
#       "Teste grátis"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus-api/"
#   },
#   {
#     "product_name": "Integrações simples e poderosas",
#     "summary": "Integra dados de processos judiciais a diversos sistemas existentes na organização.",
#     "key_features": [
#       "Definição de regras de negócio",
#       "Automatização de fluxos de decisão",
#       "APIs projetadas para se adequarem à operação"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus-api/"
#   },
#   {
#     "product_name": "Predictus Plataforma",
#     "summary": "Plataforma web que democratiza o acesso a dados de processos judiciais, permitindo consultas instantâneas em nível nacional diretamente do navegador.",
#     "key_features": [
#       "Consultas instantâneas de processos judiciais",
#       "Dados organizados e estruturados sem necessidade de integração",
#       "Facilidade de compreensão e download das informações",
#       "Ideal para usuários B2B"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Consultas para Análise de Crédito e Risco",
#     "summary": "Permite que instituições financeiras acessem o histórico judicial de potenciais clientes para identificar comportamentos de risco.",
#     "key_features": [
#       "Identificação de inadimplência e antecedentes criminais",
#       "Acesso a dados judiciais relevantes para análise de crédito"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Acompanhamento de Processos",
#     "summary": "Facilita o acompanhamento de ações judiciais próprias de empresas através da busca periódica pelo CNPJ.",
#     "key_features": [
#       "Identificação rápida de processos recém distribuídos",
#       "Ideal para departamentos jurídicos"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Avaliação Judicial para NPLs e Ativos Estressados",
#     "summary": "Utiliza consultas de processos judiciais para avaliar ativos e passivos de devedores, proporcionando uma visão ampla do risco.",
#     "key_features": [
#       "Avaliação de ativos inadimplidos",
#       "Informações detalhadas sobre a situação judicial dos devedores"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Análise Processual para Locação Segura de Imóveis",
#     "summary": "Auxilia garantidoras de aluguel na avaliação de riscos de potenciais clientes através da consulta de processos.",
#     "key_features": [
#       "Verificação de ações de despejo e inadimplência",
#       "Proteção contra prejuízos para empresas e proprietários"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Consultas Judiciais para Compliance",
#     "summary": "Potencializa o background check e a due diligence com consultas instantâneas de processos judiciais.",
#     "key_features": [
#       "Investigação do histórico judicial de empresas e colaboradores",
#       "Acesso a dados detalhados de antecedentes criminais, cíveis e trabalhistas"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Busca de Leads para Aquisição de Ativos Judiciais",
#     "summary": "Permite encontrar leads através de processos judiciais, potencializando a geração de demanda.",
#     "key_features": [
#       "Filtros de busca personalizados",
#       "Informações detalhadas sobre ações judiciais"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Homologação de Fornecedores",
#     "summary": "Consulta a situação judicial de fornecedores para identificar riscos associados.",
#     "key_features": [
#       "Acesso a informações criminais, cíveis e trabalhistas",
#       "Garantia de relações saudáveis e éticas"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Gerenciamento de Riscos no Transporte de Cargas",
#     "summary": "Consulta criminal para garantir a conformidade legal no transporte de cargas, conforme a Lei nº 13.640/2018.",
#     "key_features": [
#       "Checagem de antecedentes do motorista",
#       "Acesso ao histórico judicial completo"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   },
#   {
#     "product_name": "Análise Judicial para Recrutamento e Seleção",
#     "summary": "Permite conhecer o histórico judicial de candidatos durante o processo de seleção.",
#     "key_features": [
#       "Consulta de antecedentes criminais",
#       "Conformidade legal nas contratações"
#     ],
#     "error": false,
#     "source_url": "https://predictus.inf.br/predictus_plataforma/"
#   }
# ]
#         ```
#
#         ## Instruções
#
#         Use o contexto acima para responder perguntas sobre:
#         - Produtos e soluções oferecidos pela Predictus
#         - Características e funcionalidades de cada solução
#         - Casos de uso e aplicações
#         - Diferenciais competitivos
#
#         Seja preciso e use as informações do contexto fornecido.

# %% [markdown]
# ## 📊 Diagrama do Workflow
#
# ```
# ┌─────────┐
# │  START  │
# └────┬────┘
#      │
#      ▼
# ┌─────────────────────┐
# │ extract_products    │  ← Extrai produtos das URLs usando Crawl4AI
# │ (Node Assíncrono)   │
# └────┬────────────────┘
#      │
#      ▼
# ┌─────────────────────┐
# │ generate_dossier    │  ← Gera dossiê completo usando LLM
# │ (Node Assíncrono)   │
# └────┬────────────────┘
#      │
#      ▼
# ┌─────────────────────┐
# │ create_prompt_      │  ← Cria template de prompt com contexto
# │ template            │
# │ (Node Assíncrono)   │
# └────┬────────────────┘
#      │
#      ▼
# ┌─────────┐
# │   END   │
# └─────────┘
# ```
#
# ### Arquivos Gerados:
# - `workflow_products.json`: Lista de produtos extraídos
# - `workflow_dossier.md`: Dossiê completo gerado pela LLM
# - `workflow_prompt_template.md`: Template de prompt com contexto
